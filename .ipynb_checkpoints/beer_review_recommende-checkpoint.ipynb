# %%
import os
import pandas as pd
import time
from datetime import datetime

# %%
os.getcwd()
# Out:
# 'C:\\Users\\KonuTech\\Downloads\\beer_reviews_recommender'

# %%
os.chdir('C:\\Users\\KonuTech\\Downloads\\beer_reviews_recommender')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\KonuTech\\Downloads\\beer_reviews_recommender'

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  'beer_reviews.csv',
#  'beer_review_recommender.ipynb',
#  'README.md']

# %%
beer_reviews["review_time"][0]
# Out:
# 1234817823

# %%
print(datetime.utcfromtimestamp(beer_reviews["review_time"][0]).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 2009-02-16 20:57:03

# %%
def epochparser(object_name, column)
    object_name[column] = datetime.utcfromtimestamp(object_name[column].strftime('%Y-%m-%d %H:%M:%S'))
    return object_name

# %%
beer_reviews["review_time"] = beer_reviews["review_time"].apply(lambda d: datetime.utcfromtimestamp(d))

# %%
def myparser(x):
    return datetime.utcfromtimestamp(int(x))

# %%
beer_reviews["review_time"][0]
# Out:
# 1234817823

# %%
beer_reviews = pd.read_csv('beer_reviews.csv', parse_dates=[2], date_parser=myparser)

# %%
beer_reviews
# Out:
#          brewery_id                 brewery_name         review_time  \
# 0             10325              Vecchio Birraio 2009-02-16 20:57:03
# 1             10325              Vecchio Birraio 2009-03-01 13:44:57
# 2             10325              Vecchio Birraio 2009-03-01 14:10:04
# 3             10325              Vecchio Birraio 2009-02-15 19:12:25
# 4              1075      Caldera Brewing Company 2010-12-30 18:53:26
# ...             ...                          ...                 ...
# 1586609       14359  The Defiant Brewing Company 2006-11-05 00:01:32
# 1586610       14359  The Defiant Brewing Company 2006-10-17 01:29:26
# 1586611       14359  The Defiant Brewing Company 2006-10-13 01:21:53
# 1586612       14359  The Defiant Brewing Company 2006-10-05 04:37:24
# 1586613       14359  The Defiant Brewing Company 2006-10-04 23:41:59
#
#          review_overall  review_aroma  review_appearance review_profilename  \
# 0                   1.5           2.0                2.5            stcules
# 1                   3.0           2.5                3.0            stcules
# 2                   3.0           2.5                3.0            stcules
# 3                   3.0           3.0                3.5            stcules
# 4                   4.0           4.5                4.0     johnmichaelsen
# ...                 ...           ...                ...                ...
# 1586609             5.0           4.0                3.5         maddogruss
# 1586610             4.0           5.0                2.5          yelterdow
# 1586611             4.5           3.5                3.0           TongoRad
# 1586612             4.0           4.5                4.5           dherling
# 1586613             5.0           4.5                4.5               cbl2
#
#                              beer_style  review_palate  review_taste  \
# 0                            Hefeweizen            1.5           1.5
# 1                    English Strong Ale            3.0           3.0
# 2                Foreign / Export Stout            3.0           3.0
# 3                       German Pilsener            2.5           3.0
# 4        American Double / Imperial IPA            4.0           4.5
# ...                                 ...            ...           ...
# 1586609                     Pumpkin Ale            4.0           4.0
# 1586610                     Pumpkin Ale            2.0           4.0
# 1586611                     Pumpkin Ale            3.5           4.0
# 1586612                     Pumpkin Ale            4.5           4.5
# 1586613                     Pumpkin Ale            4.5           4.5
#
#                       beer_name  beer_abv  beer_beerid
# 0                  Sausa Weizen       5.0        47986
# 1                      Red Moon       6.2        48213
# 2        Black Horse Black Beer       6.5        48215
# 3                    Sausa Pils       5.0        47969
# 4                 Cauldron DIPA       7.7        64883
# ...                         ...       ...          ...
# 1586609      The Horseman's Ale       5.2        33061
# 1586610      The Horseman's Ale       5.2        33061
# 1586611      The Horseman's Ale       5.2        33061
# 1586612      The Horseman's Ale       5.2        33061
# 1586613      The Horseman's Ale       5.2        33061
#
# [1586614 rows x 13 columns]

# %%
beer_reviews = pd.read_csv('beer_reviews.csv', parse_dates=['review_time'], date_parser=myparser)

# %%
beer_reviews.date.apply(lambda d: datetime.strptime(d, "%Y-%m-%d"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-173171f63408> in <module>
# ----> 1 beer_reviews.date.apply(lambda d: datetime.strptime(d, "%Y-%m-%d"))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'date'

# %%
beer_reviews = pd.read_csv('beer_reviews.csv', parse_dates=['review_time'], date_parser=myparser)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in converter(*date_cols)
#    3360                 result = tools.to_datetime(
# -> 3361                     date_parser(*date_cols), errors="ignore", cache=cache_dates
#    3362                 )
#
# <ipython-input-39-24e6d8a9321d> in myparser(date)
#       3     for d in date:
# ----> 4         data.append(dt.datetime.fromtimestamp(date))
#       5     return data
#
# TypeError: only size-1 arrays can be converted to Python scalars
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in converter(*date_cols)
#    3371                             parser=date_parser,
# -> 3372                             dayfirst=dayfirst,
#    3373                         ),
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.try_parse_dates()
#
# <ipython-input-39-24e6d8a9321d> in myparser(date)
#       3     for d in date:
# ----> 4         data.append(dt.datetime.fromtimestamp(date))
#       5     return data
#
# TypeError: an integer is required (got type str)
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-d1119ffa2e69> in <module>
# ----> 1 beer_reviews = pd.read_csv('beer_reviews.csv', parse_dates=['review_time'], date_parser=myparser)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     458
#     459     try:
# --> 460         data = parser.read(nrows)
#     461     finally:
#     462         parser.close()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1196     def read(self, nrows=None):
#    1197         nrows = _validate_integer("nrows", nrows)
# -> 1198         ret = self._engine.read(nrows)
#    1199
#    1200         # May alter columns / col_dict
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2230             data = {k: v for k, (i, v) in zip(names, data)}
#    2231
# -> 2232             names, data = self._do_date_conversions(names, data)
#    2233             index, names = self._make_index(data, alldata, names)
#    2234
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _do_date_conversions(self, names, data)
#    1970                 self.index_names,
#    1971                 names,
# -> 1972                 keep_date_col=self.keep_date_col,
#    1973             )
#    1974
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _process_date_conversion(data_dict, converter, parse_spec, index_col, index_names, columns, keep_date_col)
#    3413                 if _isindex(colspec):
#    3414                     continue
# -> 3415                 data_dict[colspec] = converter(data_dict[colspec])
#    3416             else:
#    3417                 new_name, col, old_names = _try_convert_dates(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in converter(*date_cols)
#    3375                     )
#    3376                 except Exception:
# -> 3377                     return generic_parser(date_parser, *date_cols)
#    3378
#    3379     return converter
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\date_converters.py in generic_parser(parse_func, *cols)
#      36     for i in range(N):
#      37         args = [c[i] for c in cols]
# ---> 38         results[i] = parse_func(*args)
#      39
#      40     return results
#
# <ipython-input-39-24e6d8a9321d> in myparser(date)
#       2     data = []
#       3     for d in date:
# ----> 4         data.append(dt.datetime.fromtimestamp(date))
#       5     return data
#
# TypeError: an integer is required (got type str)

# %%
beer_reviews
# Out:
#          brewery_id                 brewery_name review_time  review_overall  \
# 0             10325              Vecchio Birraio  1234817823             1.5
# 1             10325              Vecchio Birraio  1235915097             3.0
# 2             10325              Vecchio Birraio  1235916604             3.0
# 3             10325              Vecchio Birraio  1234725145             3.0
# 4              1075      Caldera Brewing Company  1293735206             4.0
# ...             ...                          ...         ...             ...
# 1586609       14359  The Defiant Brewing Company  1162684892             5.0
# 1586610       14359  The Defiant Brewing Company  1161048566             4.0
# 1586611       14359  The Defiant Brewing Company  1160702513             4.5
# 1586612       14359  The Defiant Brewing Company  1160023044             4.0
# 1586613       14359  The Defiant Brewing Company  1160005319             5.0
#
#          review_aroma  review_appearance review_profilename  \
# 0                 2.0                2.5            stcules
# 1                 2.5                3.0            stcules
# 2                 2.5                3.0            stcules
# 3                 3.0                3.5            stcules
# 4                 4.5                4.0     johnmichaelsen
# ...               ...                ...                ...
# 1586609           4.0                3.5         maddogruss
# 1586610           5.0                2.5          yelterdow
# 1586611           3.5                3.0           TongoRad
# 1586612           4.5                4.5           dherling
# 1586613           4.5                4.5               cbl2
#
#                              beer_style  review_palate  review_taste  \
# 0                            Hefeweizen            1.5           1.5
# 1                    English Strong Ale            3.0           3.0
# 2                Foreign / Export Stout            3.0           3.0
# 3                       German Pilsener            2.5           3.0
# 4        American Double / Imperial IPA            4.0           4.5
# ...                                 ...            ...           ...
# 1586609                     Pumpkin Ale            4.0           4.0
# 1586610                     Pumpkin Ale            2.0           4.0
# 1586611                     Pumpkin Ale            3.5           4.0
# 1586612                     Pumpkin Ale            4.5           4.5
# 1586613                     Pumpkin Ale            4.5           4.5
#
#                       beer_name  beer_abv  beer_beerid
# 0                  Sausa Weizen       5.0        47986
# 1                      Red Moon       6.2        48213
# 2        Black Horse Black Beer       6.5        48215
# 3                    Sausa Pils       5.0        47969
# 4                 Cauldron DIPA       7.7        64883
# ...                         ...       ...          ...
# 1586609      The Horseman's Ale       5.2        33061
# 1586610      The Horseman's Ale       5.2        33061
# 1586611      The Horseman's Ale       5.2        33061
# 1586612      The Horseman's Ale       5.2        33061
# 1586613      The Horseman's Ale       5.2        33061
#
# [1586614 rows x 13 columns]
